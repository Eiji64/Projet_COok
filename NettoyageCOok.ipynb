# %% [markdown]
# ## J'importe mes bibiothèques

# %%
import pandas as pd

# %%
import plotly.graph_objects as go

# %% [markdown]
# ## Je charge mon fichier

# %%
# Import du fichier excel et de sa page 'Synthese'
df = pd.read_excel("datas/AGRIBALYSE3.1_produits alimentaires_2.xlsm", sheet_name="Synthese")

# %%
df.head(10)
# Out:
#    Unnamed: 0    Unnamed: 1                              Unnamed: 2  \
# 1   Code\nAGB  Code\nCIQUAL                        Groupe d'aliment
# 2       11084         11084  aides culinaires et ingrédients divers
# 3       11023         11023  aides culinaires et ingrédients divers
# 4       11000         11000  aides culinaires et ingrédients divers
# 5       11093         11093  aides culinaires et ingrédients divers
# 6       20995         20995  aides culinaires et ingrédients divers
# 7       20998         20998  aides culinaires et ingrédients divers
# 8       37000         37000  aides culinaires et ingrédients divers
# 9       37002         37002  aides culinaires et ingrédients divers
# 10      11033         11033  aides culinaires et ingrédients divers
#
#                  Synthèse                                         Unnamed: 4  \
# 1   Sous-groupe d'aliment                         Nom du Produit en Français
# ...

# %% [markdown]
# ## Suppresion de la  premiere ligne

# %%
# Les premieres lignes sont fusionner à l'index 0

df = df.drop([0])
df.head(10)
# Out:
#    Unnamed: 0    Unnamed: 1                              Unnamed: 2  \
# 1   Code\nAGB  Code\nCIQUAL                        Groupe d'aliment
# 2       11084         11084  aides culinaires et ingrédients divers
# 3       11023         11023  aides culinaires et ingrédients divers
# 4       11000         11000  aides culinaires et ingrédients divers
# 5       11093         11093  aides culinaires et ingrédients divers
# 6       20995         20995  aides culinaires et ingrédients divers
# 7       20998         20998  aides culinaires et ingrédients divers
# 8       37000         37000  aides culinaires et ingrédients divers
# 9       37002         37002  aides culinaires et ingrédients divers
# 10      11033         11033  aides culinaires et ingrédients divers
#
#                  Synthèse                                         Unnamed: 4  \
# 1   Sous-groupe d'aliment                         Nom du Produit en Français
# ...

# %%
noms_colonnes = df.iloc[0].tolist()
noms_colonnes
# Out:
# ['Code\nAGB',
#  'Code\nCIQUAL',
#  "Groupe d'aliment",
#  "Sous-groupe d'aliment",
#  'Nom du Produit en Français',
#  'LCI Name',
#  'code saison (0 : hors saison ; 1 : de saison ; 2 : mix de consommation FR)',
#  'code avion (1 : par avion)',
#  'Livraison',
#  "Matériau d'emballage",
#  'Préparation',
#  'DQR - Note de qualité de la donnée (1 excellente ; 5 très faible)',
#  'mPt/kg de produit',
#  'kg CO2 eq/kg de produit',
#  'kg CVC11 eq/kg de produit',
#  'kBq U-235 eq/kg de produit',
#  'kg NMVOC eq/kg de produit',
#  'disease inc./kg de produit',
#  'CTUh/kg de produit',
#  'CTUh/kg de produit',
#  'mol H+ eq/kg de produit',
#  'kg P eq/kg de produit',
#  'kg N eq/kg de produit',
#  'mol N eq/kg de produit',
#  'CTUe/kg de produit',
#  'Pt/kg de produit',
#  'm3 depriv./kg de produit',
#  'MJ/kg de produit',
#  'kg Sb eq/kg de produit']

# %%
df.rename(columns=dict(zip(df.columns, noms_colonnes)), inplace=True)
df.head(10)
# Out:
#     Code\nAGB  Code\nCIQUAL                        Groupe d'aliment  \
# 1   Code\nAGB  Code\nCIQUAL                        Groupe d'aliment
# 2       11084         11084  aides culinaires et ingrédients divers
# 3       11023         11023  aides culinaires et ingrédients divers
# 4       11000         11000  aides culinaires et ingrédients divers
# 5       11093         11093  aides culinaires et ingrédients divers
# 6       20995         20995  aides culinaires et ingrédients divers
# 7       20998         20998  aides culinaires et ingrédients divers
# 8       37000         37000  aides culinaires et ingrédients divers
# 9       37002         37002  aides culinaires et ingrédients divers
# 10      11033         11033  aides culinaires et ingrédients divers
#
#     Sous-groupe d'aliment                         Nom du Produit en Français  \
# 1   Sous-groupe d'aliment                         Nom du Produit en Français
# ...

# %%
df2 = df.drop([1])
df2.head(10)
# Out:
#    Code\nAGB Code\nCIQUAL                        Groupe d'aliment  \
# 2      11084        11084  aides culinaires et ingrédients divers
# 3      11023        11023  aides culinaires et ingrédients divers
# 4      11000        11000  aides culinaires et ingrédients divers
# 5      11093        11093  aides culinaires et ingrédients divers
# 6      20995        20995  aides culinaires et ingrédients divers
# 7      20998        20998  aides culinaires et ingrédients divers
# 8      37000        37000  aides culinaires et ingrédients divers
# 9      37002        37002  aides culinaires et ingrédients divers
# 10     11033        11033  aides culinaires et ingrédients divers
# 11     11032        11032  aides culinaires et ingrédients divers
#
#    Sous-groupe d'aliment                         Nom du Produit en Français  \
# 2                 algues                                  Agar (algue), cru
# 3                 herbes                                  Ail séché, poudre
# ...

# %% [markdown]
# ## Choix de colonnes à garder

# %%
colonnes_synthese_conservees = ['Code\nAGB',
 'Code\nCIQUAL',
 "Groupe d'aliment",
 "Sous-groupe d'aliment",
 'Nom du Produit en Français',
 'LCI Name','kg CO2 eq/kg de produit']

df_synthese = df2[colonnes_synthese_conservees].copy()

# %%
df_synthese.to_csv('datas/page_synthese.csv')

# %% [markdown]
# ## Import de la page detail etape

# %%
df_detail_etape = pd.read_excel("datas/AGRIBALYSE3.1_produits alimentaires_2.xlsm", sheet_name="Detail etape")

# %%
df_detail_etape.head()
# Out:
#   Unnamed: 0   Unnamed: 1  \
# 0        NaN          NaN
# 1   Code AGB  Code CIQUAL
# 2      11084        11084
# 3      11023        11023
# 4      11000        11000
#
#   Résultats par étape\nL'arrondi des données peut causer des différences entre la somme des 6 étapes et la Synthèse.\nLa valeur zéro est exprimée "-"  \
# 0                                                NaN
# 1                                   Groupe d'aliment
# 2             aides culinaires et ingrédients divers
# 3             aides culinaires et ingrédients divers
# 4             aides culinaires et ingrédients divers
#
#               Unnamed: 3                  Unnamed: 4             Unnamed: 5  \
# 0                    NaN                         NaN                    NaN
# 1  Sous-groupe d'aliment  Nom du Produit en Français               LCI Name
# 2                 algues           Agar (algue), cru     Seaweed, agar, raw
# 3                 herbes           Ail séché, poudre  Garlic, powder, dried
# ...

# %% [markdown]
# ## Conservation des colonnes d'interet

# %%
colonnes_conservees = df_detail_etape.columns[0:6].tolist() + df_detail_etape.columns[15:22].tolist()
df_detail_etape = df_detail_etape[colonnes_conservees]
df_detail_etape.head()
# Out:
#   Unnamed: 0   Unnamed: 1  \
# 0        NaN          NaN
# 1   Code AGB  Code CIQUAL
# 2      11084        11084
# 3      11023        11023
# 4      11000        11000
#
#   Résultats par étape\nL'arrondi des données peut causer des différences entre la somme des 6 étapes et la Synthèse.\nLa valeur zéro est exprimée "-"  \
# 0                                                NaN
# 1                                   Groupe d'aliment
# 2             aides culinaires et ingrédients divers
# 3             aides culinaires et ingrédients divers
# 4             aides culinaires et ingrédients divers
#
#               Unnamed: 3                  Unnamed: 4             Unnamed: 5  \
# 0                    NaN                         NaN                    NaN
# 1  Sous-groupe d'aliment  Nom du Produit en Français               LCI Name
# 2                 algues           Agar (algue), cru     Seaweed, agar, raw
# 3                 herbes           Ail séché, poudre  Garlic, powder, dried
# ...

# %% [markdown]
# ## Sauvegarde des bons noms de colonnes dans une variable

# %%
noms_colonnes_detail = df_detail_etape.iloc[1].tolist()
noms_colonnes_detail
# Out:
# ['Code AGB',
#  'Code CIQUAL',
#  "Groupe d'aliment",
#  "Sous-groupe d'aliment",
#  'Nom du Produit en Français',
#  'LCI Name',
#  'Agriculture',
#  'Transformation',
#  'Emballage',
#  'Transport',
#  'Supermarché et distribution',
#  'Consommation',
#  'Total']

# %% [markdown]
# ## Je renomme correctement les colonnes

# %%
df_detail_etape.rename(columns=dict(zip(df_detail_etape.columns, noms_colonnes_detail)), inplace=True)
df_detail_etape.head()
# Out:
#    Code AGB  Code CIQUAL                        Groupe d'aliment  \
# 0       NaN          NaN                                     NaN
# 1  Code AGB  Code CIQUAL                        Groupe d'aliment
# 2     11084        11084  aides culinaires et ingrédients divers
# 3     11023        11023  aides culinaires et ingrédients divers
# 4     11000        11000  aides culinaires et ingrédients divers
#
#    Sous-groupe d'aliment  Nom du Produit en Français               LCI Name  \
# 0                    NaN                         NaN                    NaN
# 1  Sous-groupe d'aliment  Nom du Produit en Français               LCI Name
# 2                 algues           Agar (algue), cru     Seaweed, agar, raw
# 3                 herbes           Ail séché, poudre  Garlic, powder, dried
# 4                 herbes                    Ail, cru          Garlic, fresh
#
#                Agriculture  Transformation  Emballage  Transport  \
# ...

# %% [markdown]
# ## Je drop les 2 premieres lignes

# %%
df_detail_etape = df_detail_etape.drop([0, 1]).reset_index(drop=True)
df_detail_etape.head()
# Out:
#   Code AGB Code CIQUAL                        Groupe d'aliment  \
# 0    11084       11084  aides culinaires et ingrédients divers
# 1    11023       11023  aides culinaires et ingrédients divers
# 2    11000       11000  aides culinaires et ingrédients divers
# 3    11093       11093  aides culinaires et ingrédients divers
# 4    20995       20995  aides culinaires et ingrédients divers
#
#   Sous-groupe d'aliment                         Nom du Produit en Français  \
# 0                algues                                  Agar (algue), cru
# 1                herbes                                  Ail séché, poudre
# 2                herbes                                           Ail, cru
# 3                herbes                                       Aneth, frais
# 4                algues  Ao-nori (Enteromorpha sp.), séchée ou déshydratée
#
#                                             LCI Name Agriculture  \
# 0                                 Seaweed, agar, raw    4.569259
# ...

# %%
comparaison = df_detail_etape.loc[df_detail_etape['Code AGB'].str != df_detail_etape['Code CIQUAL'].str].index.tolist()

comparaison
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[120], line 1
# ----> 1 comparaison = df_detail_etape.loc[df_detail_etape['Code AGB'].str != df_detail_etape['Code CIQUAL'].str].index.tolist()
#       3 comparaison
#
# File c:\Users\dojie\OneDrive\Documents\Formation Data Analyst\Python\Projet COok\Cook\Lib\site-packages\pandas\core\indexing.py:1103, in _LocationIndexer.__getitem__(self, key)
#    1100 axis = self.axis or 0
#    1102 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\dojie\OneDrive\Documents\Formation Data Analyst\Python\Projet COok\Cook\Lib\site-packages\pandas\core\indexing.py:1342, in _LocIndexer._getitem_axis(self, key, axis)
#    1339         return self.obj.iloc[tuple(indexer)]
#    1341 # fall thru to straight lookup
# -> 1342 self._validate_key(key, axis)
# ...

# %% [markdown]
# ## Verifier si le code AGB et CIQUAL sont toujours les meme

# %%
df['Code AGB'].astype
